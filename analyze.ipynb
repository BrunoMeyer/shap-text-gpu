# %%
import pandas as pd

# %%
cuda = pd.read_csv('cuda_shap_summary.csv')
permutation = pd.read_csv('permutation_shap_summary.csv')

# %%
cuda
# Out:
#      sample  class     logit      time top1_token  top1_shap top2_token  \
# 0         0      0 -0.787300  0.019701      batch   1.942860       miss
# 1         1      0 -1.931633  0.019661       such   1.305200    therein
# 2         2      0  2.092304  0.019660     nearly   2.492000      monty
# 3         3      0 -2.289356  0.019662       talk   1.826700    funding
# 4         4      0  3.462380  0.019692     scenes   1.963100     saying
# ..      ...    ...       ...       ...        ...        ...        ...
# 251     251      0 -2.969842  0.019676    one-man   1.235360      sense
# 252     252      0 -3.640087  0.019669       line   1.231130       kill
# 253     253      0  3.105544  0.019659       save   3.001900       case
# 254     254      0 -2.928005  0.019660        low   1.684920      video
# 255     255      0 -3.702160  0.019664     wasted   0.941881        but
#
#      top2_shap top3_token  top3_shap  ... bottom1_token  bottom1_shap  \
# ...

# %%
cuda["time"].sum()
# Out:
# np.float64(5.076195)

# %%
permutation["time"].sum()
# Out:
# np.float64(599.1659999999999)

# %%
cuda["time"].mean()
# Out:
# np.float64(0.01982888671875)

# %%
permutation["time"].mean()
# Out:
# np.float64(2.3404921874999998)
